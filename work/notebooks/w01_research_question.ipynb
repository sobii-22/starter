# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sobii-22/starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# My lane: Content decay and search performance
#
# I want to explore why some webpages lose search visibility and traffic over time. I'm interested in using machine learning to identify patterns in content age, impressions, position, and engagement that may help explain when a page starts declining. This interests me because it connects data analysis with a practical question: how can we recognize content that may need improvement before its performance drops significantly?

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# My work aims to improve the decision of which webpages should be prioritized for SEO review or content updates. SEO specialists, content managers, or website owners would act on the recommendation by reviewing, refreshing, or optimizing selected pages. A wrong recommendation could waste time and resources if a healthy page is updated unnecessarily, while failing to identify a declining page could result in lost impressions, clicks, and organic traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
#
# A quick look at the dataset shows that search position is strongly associated with click-through rate. Among pages with at least 100 impressions, the mean CTR is **0.3341 for top-three results**, compared with **0.0554 for deep-ranking pages**. Pages in the `page_1` tier have a mean CTR of **0.3548**, while pages in the `page_3_5` tier average **0.1424**.
#
# These differences suggest that ranking position and content performance are worth investigating further. Over the next seven weeks, I want to explore whether factors such as content age, update history, impressions, and content type can help explain performance differences and identify pages that may need optimization.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
#
# My work will be able to identify observed patterns and relationships in the dataset, such as whether CTR differs across ranking positions, content types, or content-age groups. The analysis may provide directional insights into which factors are associated with stronger or weaker search performance. It can also support decisions about which pages may deserve further review or optimization.
#
# However, the work will not prove that one factor directly causes another. It will not establish that updating content will definitely increase traffic, and it will not predict or explain Google’s ranking algorithm. Any model results should be treated as decision-support evidence rather than guaranteed outcomes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
